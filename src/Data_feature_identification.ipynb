# %%
import laspy
import os
import pandas as pd

# %%
input_file_las = '/home/ajai-krishna/work/GEO_AI/data/input/laz/DEVDI_POINT CLOUD (511671).las'

# %%
output_subset_dir = '/home/ajai-krishna/work/GEO_AI/outputs/subsets/'

# %%
las = laspy.open(input_file_las)
header = las.header
variables = list(las.header.point_format.dimension_names)
print(variables)
# Out:
# ['X', 'Y', 'Z', 'intensity', 'return_number', 'number_of_returns', 'scan_direction_flag', 'edge_of_flight_line', 'classification', 'synthetic', 'key_point', 'withheld', 'scan_angle_rank', 'user_data', 'point_source_id', 'red', 'green', 'blue', 'normal x', 'normal y', 'normal z']
