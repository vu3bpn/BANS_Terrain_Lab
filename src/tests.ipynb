# %%
from config import *
from misc_utilities import *
'''subset each scene into 5x5 sub scenes'''
las_input_filenames = list(Path(input_laz_dir).rglob("*.las"))
for las_file in las_input_filenames:  
    split_into(las_file,10)
# Out:
# window size 110.02400000000198 for /mnt/nvme1n1/Bipin/Scripts/geo_ai/src/../data/input/laz/Gujrat_Point_Cloud/DEVDI_POINT CLOUD (511671).las
# 100%|██████████| 90/90 [07:54<00:00,  5.28s/it]
# window size 62.01120000001974 for /mnt/nvme1n1/Bipin/Scripts/geo_ai/src/../data/input/laz/Punjab_Point_Cloud/Dhal_Hoshiarpur_31235.las
# 100%|██████████| 100/100 [03:09<00:00,  1.89s/it]
# window size 97.85750000000007 for /mnt/nvme1n1/Bipin/Scripts/geo_ai/src/../data/input/laz/Rajasthan_Point_Cloud/64334_2H_(REFLIGHT)_POINT_CLOUD.las
# 100%|██████████| 100/100 [07:41<00:00,  4.62s/it]
# window size 99.67400000002235 for /mnt/nvme1n1/Bipin/Scripts/geo_ai/src/../data/input/laz/Rajasthan_Point_Cloud/67169_5NKR_CHAKHIRASINGH.las
# 100%|██████████| 100/100 [01:19<00:00,  1.26it/s]
# window size 0.002168912000000489 for /mnt/nvme1n1/Bipin/Scripts/geo_ai/src/../data/input/laz/Tamil Nadu_Point_Cloud/THANDALAM.las
#  11%|█▏        | 9/80 [02:14<17:32, 14.82s/it]

# %%
from config import *
import os
base_dir
os.listdir(base_dir)

# %%
from data_download import *
download_data()
extract_data()

# %%
from DTM_pre_processing import *
from config import *
las_input_filenames = list(Path(input_laz_dir).rglob("*.laz"))   
with Pool(pipeline_cuncurrent_jobs) as p:
    p.map(run_dtm_pipeline,las_input_filenames)
